# %%
#pizza order programme
print("Heyyy!!! \n welcome to pizza hut")
print("what size of pizza do you want??")
print("Small, Medium, Large")
pizza = input("input first letter of size of pizza you intend to order in").lower()
if pizza == "s":
    price = 15
    print("do you want pepperoni??")
    pepperoni = input("Input 'y' for yes and 'n' for no").lower()
    if pepperoni == "y":
        price += 2
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
    elif pepperoni == "n":
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
elif pizza == "m":
    price = 20
    print("do you want pepperoni??")
    pepperoni = input("Input 'y' for yes and 'n' for no").lower()
    if pepperoni == "y":
        price += 3
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
    elif pepperoni == "n":
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
elif pizza == "l":
    price = 25
    print("do you want pepperoni??")
    pepperoni = input("Input 'y' for yes and 'n' for no").lower()
    if pepperoni == "y":
        price += 3
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
    elif pepperoni == "n":
        print("Do you want extra cheese")
        cheese = input("Input 'y' for yes and 'n' for no").lower()
        if cheese == "y":
            price += 1
            print(f"your bill is ${price}")
        else:
            print(f"your bill is ${price}")
else:
    print("wrong input")
