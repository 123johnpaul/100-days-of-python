# %%
print('''                _
                          _dP"9b_
                        _dP"   "9b_
                      _dP"       "9b_
                    _dP"           "9b_
        8888888888888888888     8888888888888888888
        88      _dP"     88     88     "9b_      88
        88      "9b_     88     88     _dP"      88
        88  _      9b_   88     88   _dP"     _  88
        88_d8b_     "9b_ 88     88 _dP"     _d8b_88
        88P" "9b_     "9b88     8_dP"     _dP" "988
      _d88     "9b_     "9P     9P"     _dP"     88b_
    _dP"88       "9b_                 _dP"       88"9b_
  _dP"  8888888888888b               dP"88888888888  "9b_
_dP"                                                   "9b_  welcome to the treasure game
"9b_                                                   _dP"  make careful decisions and you will get to the end of the story eventually 
  "9b_  8888888888888P             9b_8888888888888  _dP"
    "9b_88       _dP"               "9b_         88_dP"
      "988     _dP"                   "9b_       88P"
        88b_ _dP"       _dP     8d_     "9b_   _d88
        88"98P"       _dP"8     889b_     "9b_dP"88
        88          _dP" 88     88 "9b_          88
        88        _dP"   88     88   "9b_        88
        88       9b_     88     88     _dP       88
        8888888888888888888     8888888888888888888
                    "9b_           _dP"
                      "9b_       _dP"
                        "9b_   _dP"
                          "9b_dP"
                             "
      ''')
print("you are at a cross road")
road = input("which way do you want to go??\nLeft or Right??").lower()
if road == "left":
    print("At the end of the path there are three doors of different colors")
    print("red, blue, and yellow respectively")
    door = input("what door do you want to follow??")
    if door == "red":
        print("You fell of a cliff\nGAMEOVER!!!")
    elif door == "blue":
        print("You have found the treasure\nYOU WIN!!!")
        print('''
               m$$$$L               d$$b    c$$$$c   d$ d$b
             J$$P  m$$$          $$ $P ?$  $$P  d$b J$$$P ?$L
             $$$b           4$$   $$P  c$  $$cc$$P  $$$
              $$$$b     $$$  $$$  $$$$$P   $$m      $$P
                 $$$b   $$$  4$$$  $$$      ?$$$$   $$P
                   $$bc  $$bd$ $$P $$P __     __     __   _
         c$$$m      $$$L  `$P        _)  \  _) |_  __) \ _)\
         # ?$$$$L   J$$$P             |  `- | |__  \ | ' / | |
           `$$$$$$$$P                \__|_/ |____/ |_|_\ |_|

                 __________________  / 3 \  ___________________
             ______________________\//   \\/________________________
                                   \'     `/
        ''')
    elif door == "yellow":
        print("You fell into lava\nGAMEOVER!!!")
    else:
        print("WRONG INPUT!!!")
else:
    print("GAMEOVER!!!")
# Out:
#                 _
#                           _dP"9b_
#                         _dP"   "9b_
#                       _dP"       "9b_
#                     _dP"           "9b_
#         8888888888888888888     8888888888888888888
#         88      _dP"     88     88     "9b_      88
#         88      "9b_     88     88     _dP"      88
#         88  _      9b_   88     88   _dP"     _  88
#         88_d8b_     "9b_ 88     88 _dP"     _d8b_88
#         88P" "9b_     "9b88     8_dP"     _dP" "988
#       _d88     "9b_     "9P     9P"     _dP"     88b_
#     _dP"88       "9b_                 _dP"       88"9b_
#   _dP"  8888888888888b               dP"88888888888  "9b_
# _dP"                                                   "9b_  welcome to the treasure game
# "9b_                                                   _dP"  make careful decisions and you will get to the end of the story eventually
#   "9b_  8888888888888P             9b_8888888888888  _dP"
# ...
